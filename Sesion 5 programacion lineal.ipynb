# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Se tienen las desigualdades
# $$50x_1 + 24x_2\leq 2400$$
# $$30x_1 + 33x_2\leq 2100$$

# %% [markdown]
# Para hacer el plot las pasamos a igualdades y despejamos para una variable.

# %% [markdown]
# $$50x_1 + 24x_2\leq 2400$$
# $$30x_1 + 33x_2\leq 2100$$

# %% [markdown]
# el despeje queda enonces como

# %% [markdown]
# $$x_2 = (2400 - 24x_1)/24$$
# $$x_2 = (2100 - 30x_1)/33$$

# %%
def x2_v1(x1):
    return (2400 - 50*x1)/24
def x2_v2(x1):
    return (2100 - 30*x1)/33

# %%
x1 = np.linspace(0, 100)

# %%
plt.plot(x1, x2_v1(x1), 'magenta') #desigualdad 1
plt.plot(x1, x2_v2(x1)) # desigualdad 2
plt.plot([45, 45], [0, 25], 'k')
plt.scatter([45, 45], [0, 25], color = "red", s = 200)
plt.plot([43, 47], [5, 5], 'r')
plt.scatter([43, 47], [5, 5], color = "green", s = 200)
plt.xlim(xmin = 25, xmax = 50)
plt.ylim(ymin = -5, ymax = 45)
plt.scatter([45], [6.25], color = 'red')
plt.fill_between(np.array([45, 45.6]), x2_v1(np.array([45, 45.6])),
                5*np.ones(2), alpha = .2, color = 'orange')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)
plt.show()

# %%
plt.plot(x1, x2_v1(x1), 'magenta') #desigualdad 1
plt.plot(x1, x2_v2(x1)) # desigualdad 2
plt.plot([45, 45], [0, 25], 'k')
plt.scatter([45, 45], [0, 25], color = "red", s = 200)
plt.plot([43, 47], [5, 5], 'r')
plt.scatter([43, 47], [5, 5], color = "green", s = 200)
plt.xlim(xmin = 44, xmax = 46)
plt.ylim(ymin = 4.5, ymax = 6.5)
plt.scatter([45], [6.25], color = 'red')
plt.fill_between(np.array([45, 45.6]), x2_v1(np.array([45, 45.6])),
                5*np.ones(2), alpha = .2, color = 'orange')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)
plt.show()

# %% [markdown]
# Ya tenemos un punto posible para la solcución, $(45, 5)$. Los otros son $(46.5, 5)$ y $(45, 6.25)$

# %%
plt.plot(x1, x2_v1(x1), 'magenta') #desigualdad 1
plt.plot(x1, x2_v2(x1)) # desigualdad 2
plt.plot([45, 45], [0, 25], 'k')
plt.scatter([45, 45], [0, 25], color = "red", s = 200)
plt.plot([43, 47], [5, 5], 'r')
plt.scatter([43, 47], [5, 5], color = "green", s = 200)
plt.xlim(xmin = 44, xmax = 46)
plt.ylim(ymin = 4.5, ymax = 6.5)
plt.scatter([45, 45, 45.6], [6.25, 5, 5], color = 'red')
plt.fill_between(np.array([45, 45.6]), x2_v1(np.array([45, 45.6])),
                5*np.ones(2), alpha = .2, color = 'orange')
plt.xlabel(r"$x_1$", fontsize = 18)
plt.ylabel(r"$x_2$", fontsize = 18)
plt.show()

# %%
import scipy.optimize as opt

# %%
#res = opt.linprog(c, A_ub=A, b_ub=b, options={'disp': True})

# %%
c  =  np.array([-1,  -1])
A  =  np.array([[50,  24], [30,  33]])
b  =  np.array([2400,  2100])
x1_bound = (45, None)
x2_bound = (5, None)

# %%
A
# Out:
# array([[50, 24],
#        [30, 33]])

# %%
res = opt.linprog(c, A_ub=A, b_ub=b, bounds=(x1_bound, x2_bound), options={'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: -51.250000
#          Iterations: 4

# %%
res
# Out:
#      fun: -51.25
#  message: 'Optimization terminated successfully.'
#      nit: 4
#    slack: array([  0.  , 543.75,   0.  ,   1.25])
#   status: 0
#  success: True
#        x: array([45.  ,  6.25])

# %% [markdown]
# En inventario teniamos 90 de x_1 y 30 de x_2

# %% [markdown]
# Actividad
#
# Mónica hace aretes y cadenitas de joyería. Es tan buena, que todo lo que hace lo vende.
#
# Le toma 30 minutos hacer un par de aretes y una hora hacer una cadenita, y como Mónica también es estudihambre, solo dispone de 10 horas a la semana para hacer las joyas. Por otra parte, el material que compra solo le alcanza para hacer 15 unidades (el par de aretes cuenta como unidad) de joyas por semana.
#
# La utilidad que le deja la venta de las joyas es \$15 en cada par de aretes y \$20 en cada cadenita.
#
# ¿Cuántos pares de aretes y cuántas cadenitas debería hacer Mónica para maximizar su utilidad?

# %% [markdown]
# Ecuaciones.

# %% [markdown]
# $$30x_1 + 60x_2\leq 600$$
# $$x_1 + x_2\leq 15$$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
$$x_2 = (600 - 60x_1)/60$$
$$x_2 = (1 - 30x_1)/33$$
